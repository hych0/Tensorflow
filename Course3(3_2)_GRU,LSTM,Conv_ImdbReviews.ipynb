# %% [markdown]
# <a href="https://colab.research.google.com/github/hych0/Tensorflow/blob/main/Course3(3_2)_GRU%2CLSTM%2CConv_ImdbReviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GRU. LSTM, Conv1D
#
# GRU : 16-18 ms/step
#
# LSTM: 17-18 ms/step
#
# Conv1D: 7-9 ms/step

# %% [markdown]
# ![Screen Shot 2021-07-26 at 6.31.07 PM.png](data:image/png;base64,...)

# %%
import tensorflow as tf
print(tf.__version__)

# !pip install -q tensorflow-datasets
# Out:
# 2.5.0

# %%
import tensorflow_datasets as tfds
imdb, info = tfds.load("imdb_reviews", with_info=True, as_supervised=True)
# Out:
# Downloading and preparing dataset imdb_reviews/plain_text/1.0.0 (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteB4VYQZ/imdb_reviews-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=25000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteB4VYQZ/imdb_reviews-test.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=25000.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteB4VYQZ/imdb_reviews-unsupervised.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=50000.0), HTML(value='')))
# WARNING:absl:Dataset is using deprecated text encoder API which will be removed soon. Please use the plain_text version of the dataset and migrate to `tensorflow_text`.
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.

# %%
import numpy as np

train_data, test_data = imdb['train'], imdb['test']

training_sentences = []
training_labels = []

testing_sentences = []
testing_labels = []

# str(s.tonumpy()) is needed in Python3 instead of just s.numpy()
for s,l in train_data:
  training_sentences.append(str(s.numpy()))
  training_labels.append(l.numpy())
  
for s,l in test_data:
  testing_sentences.append(str(s.numpy()))
  testing_labels.append(l.numpy())
  
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type='post'
oov_tok = "<OOV>"


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences,maxlen=max_length, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length)

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_review(padded[1]))
print(training_sentences[1])
# Out:
# ? ? ? ? ? ? ? b'i have been known to fall asleep during films but this is usually due to a combination of things including really tired being warm and comfortable on the <OOV> and having just eaten a lot however on this occasion i fell asleep because the film was rubbish the plot development was constant constantly slow and boring things seemed to happen but with no explanation of what was causing them or why i admit i may have missed part of the film but i watched the majority of it and everything just seemed to happen of its own <OOV> without any real concern for anything else i cant recommend this film at all '
# b'I have been known to fall asleep during films, but this is usually due to a combination of things including, really tired, being warm and comfortable on the sette and having just eaten a lot. However on this occasion I fell asleep because the film was rubbish. The plot development was constant. Constantly slow and boring. Things seemed to happen, but with no explanation of what was causing them or why. I admit, I may have missed part of the film, but i watched the majority of it and everything just seemed to happen of its own accord without any real concern for anything else. I cant recommend this film at all.'

# %% [markdown]
# # Model Definition with GRU

# %%
# Model Definition with GRU
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 120, 16)           160000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 64)                9600
# _________________________________________________________________
# dense (Dense)                (None, 6)                 390
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 169,997
# Trainable params: 169,997
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 50
history = model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Epoch 1/50
# 782/782 [==============================] - 22s 17ms/step - loss: 0.4934 - accuracy: 0.7392 - val_loss: 0.3504 - val_accuracy: 0.8434
# Epoch 2/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.2946 - accuracy: 0.8792 - val_loss: 0.3485 - val_accuracy: 0.8490
# Epoch 3/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.2295 - accuracy: 0.9105 - val_loss: 0.4004 - val_accuracy: 0.8426
# Epoch 4/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.1786 - accuracy: 0.9353 - val_loss: 0.4468 - val_accuracy: 0.8318
# Epoch 5/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.1352 - accuracy: 0.9509 - val_loss: 0.4923 - val_accuracy: 0.8312
# Epoch 6/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.1023 - accuracy: 0.9639 - val_loss: 0.5868 - val_accuracy: 0.8242
# Epoch 7/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0744 - accuracy: 0.9738 - val_loss: 0.6851 - val_accuracy: 0.8212
# Epoch 8/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0516 - accuracy: 0.9824 - val_loss: 0.7450 - val_accuracy: 0.8162
# Epoch 9/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0371 - accuracy: 0.9874 - val_loss: 0.8589 - val_accuracy: 0.8186
# Epoch 10/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0285 - accuracy: 0.9900 - val_loss: 0.8488 - val_accuracy: 0.8107
# Epoch 11/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0212 - accuracy: 0.9930 - val_loss: 1.0014 - val_accuracy: 0.8167
# Epoch 12/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0242 - accuracy: 0.9924 - val_loss: 0.9278 - val_accuracy: 0.8170
# Epoch 13/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0119 - accuracy: 0.9966 - val_loss: 1.0930 - val_accuracy: 0.8160
# Epoch 14/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0136 - accuracy: 0.9957 - val_loss: 1.1837 - val_accuracy: 0.8157
# Epoch 15/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 1.2115 - val_accuracy: 0.8156
# Epoch 16/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 1.1991 - val_accuracy: 0.8097
# Epoch 17/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0104 - accuracy: 0.9969 - val_loss: 1.3622 - val_accuracy: 0.8162
# Epoch 18/50
# 782/782 [==============================] - 13s 16ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 1.3190 - val_accuracy: 0.8142
# Epoch 19/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0120 - accuracy: 0.9959 - val_loss: 1.1215 - val_accuracy: 0.8140
# Epoch 20/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 1.3116 - val_accuracy: 0.8099
# Epoch 21/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 1.4100 - val_accuracy: 0.8138
# Epoch 22/50
# 782/782 [==============================] - 13s 16ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 1.4362 - val_accuracy: 0.8100
# Epoch 23/50
# 782/782 [==============================] - 13s 16ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 1.4453 - val_accuracy: 0.8144
# Epoch 24/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0115 - accuracy: 0.9959 - val_loss: 1.3053 - val_accuracy: 0.8144
# Epoch 25/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0049 - accuracy: 0.9987 - val_loss: 1.4013 - val_accuracy: 0.8138
# Epoch 26/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 1.3482 - val_accuracy: 0.8128
# Epoch 27/50
# 782/782 [==============================] - 13s 16ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 1.4890 - val_accuracy: 0.8126
# Epoch 28/50
# 782/782 [==============================] - 13s 16ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 1.5178 - val_accuracy: 0.8140
# Epoch 29/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 1.4155 - val_accuracy: 0.8090
# Epoch 30/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 1.4400 - val_accuracy: 0.8118
# Epoch 31/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 1.3939 - val_accuracy: 0.8172
# Epoch 32/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 1.5810 - val_accuracy: 0.8083
# Epoch 33/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 1.5182 - val_accuracy: 0.8144
# Epoch 34/50
# 782/782 [==============================] - 13s 16ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 1.4708 - val_accuracy: 0.8100
# Epoch 35/50
# 782/782 [==============================] - 13s 16ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 1.6710 - val_accuracy: 0.8090
# Epoch 36/50
# 782/782 [==============================] - 13s 16ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 1.4992 - val_accuracy: 0.8137
# Epoch 37/50
# 782/782 [==============================] - 14s 18ms/step - loss: 8.1762e-04 - accuracy: 0.9998 - val_loss: 1.5230 - val_accuracy: 0.8122
# Epoch 38/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 1.5024 - val_accuracy: 0.8123
# Epoch 39/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 1.6050 - val_accuracy: 0.8120
# Epoch 40/50
# 782/782 [==============================] - 13s 16ms/step - loss: 1.6643e-04 - accuracy: 1.0000 - val_loss: 1.6711 - val_accuracy: 0.8128
# Epoch 41/50
# 782/782 [==============================] - 13s 16ms/step - loss: 1.9032e-05 - accuracy: 1.0000 - val_loss: 1.7107 - val_accuracy: 0.8131
# Epoch 42/50
# 782/782 [==============================] - 14s 18ms/step - loss: 1.2129e-05 - accuracy: 1.0000 - val_loss: 1.7510 - val_accuracy: 0.8134
# Epoch 43/50
# 782/782 [==============================] - 14s 18ms/step - loss: 8.7695e-06 - accuracy: 1.0000 - val_loss: 1.7927 - val_accuracy: 0.8133
# Epoch 44/50
# 782/782 [==============================] - 13s 16ms/step - loss: 6.3474e-06 - accuracy: 1.0000 - val_loss: 1.8371 - val_accuracy: 0.8136
# Epoch 45/50
# 782/782 [==============================] - 13s 16ms/step - loss: 4.5184e-06 - accuracy: 1.0000 - val_loss: 1.8855 - val_accuracy: 0.8138
# Epoch 46/50
# 782/782 [==============================] - 13s 16ms/step - loss: 3.1775e-06 - accuracy: 1.0000 - val_loss: 1.9382 - val_accuracy: 0.8140
# Epoch 47/50
# 782/782 [==============================] - 14s 17ms/step - loss: 2.2102e-06 - accuracy: 1.0000 - val_loss: 1.9929 - val_accuracy: 0.8140
# Epoch 48/50
# 782/782 [==============================] - 14s 18ms/step - loss: 1.5236e-06 - accuracy: 1.0000 - val_loss: 2.0497 - val_accuracy: 0.8140
# Epoch 49/50
# 782/782 [==============================] - 13s 16ms/step - loss: 1.0351e-06 - accuracy: 1.0000 - val_loss: 2.1099 - val_accuracy: 0.8142
# Epoch 50/50
# 782/782 [==============================] - 13s 16ms/step - loss: 7.0008e-07 - accuracy: 1.0000 - val_loss: 2.1733 - val_accuracy: 0.8142

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %% [markdown]
# # Model Definition with LSTM

# %%
# Model Definition with LSTM
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

history = model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 120, 16)           160000
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 64)                12544
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 390
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 172,941
# Trainable params: 172,941
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 782/782 [==============================] - 17s 19ms/step - loss: 0.4720 - accuracy: 0.7644 - val_loss: 0.3712 - val_accuracy: 0.8391
# Epoch 2/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.2973 - accuracy: 0.8812 - val_loss: 0.3526 - val_accuracy: 0.8438
# Epoch 3/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.2391 - accuracy: 0.9076 - val_loss: 0.3954 - val_accuracy: 0.8358
# Epoch 4/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.1919 - accuracy: 0.9288 - val_loss: 0.4335 - val_accuracy: 0.8335
# Epoch 5/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.1458 - accuracy: 0.9468 - val_loss: 0.4531 - val_accuracy: 0.8294
# Epoch 6/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.1065 - accuracy: 0.9629 - val_loss: 0.5199 - val_accuracy: 0.8217
# Epoch 7/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0807 - accuracy: 0.9723 - val_loss: 0.6512 - val_accuracy: 0.8191
# Epoch 8/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0599 - accuracy: 0.9804 - val_loss: 0.6464 - val_accuracy: 0.8171
# Epoch 9/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0459 - accuracy: 0.9849 - val_loss: 0.7552 - val_accuracy: 0.8183
# Epoch 10/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0386 - accuracy: 0.9864 - val_loss: 0.8918 - val_accuracy: 0.8178
# Epoch 11/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0375 - accuracy: 0.9872 - val_loss: 0.7661 - val_accuracy: 0.8169
# Epoch 12/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0202 - accuracy: 0.9940 - val_loss: 0.9002 - val_accuracy: 0.8192
# Epoch 13/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0225 - accuracy: 0.9925 - val_loss: 1.0002 - val_accuracy: 0.8104
# Epoch 14/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0168 - accuracy: 0.9947 - val_loss: 1.0324 - val_accuracy: 0.8188
# Epoch 15/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0190 - accuracy: 0.9937 - val_loss: 0.9393 - val_accuracy: 0.8014
# Epoch 16/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0278 - accuracy: 0.9908 - val_loss: 0.9849 - val_accuracy: 0.8188
# Epoch 17/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 1.1986 - val_accuracy: 0.8179
# Epoch 18/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 1.2300 - val_accuracy: 0.8166
# Epoch 19/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0117 - accuracy: 0.9967 - val_loss: 1.1777 - val_accuracy: 0.8069
# Epoch 20/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0175 - accuracy: 0.9940 - val_loss: 0.9821 - val_accuracy: 0.8102
# Epoch 21/50
# 782/782 [==============================] - 14s 17ms/step - loss: 0.0101 - accuracy: 0.9966 - val_loss: 1.0854 - val_accuracy: 0.8152
# Epoch 22/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0102 - accuracy: 0.9966 - val_loss: 1.0837 - val_accuracy: 0.8079
# Epoch 23/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0095 - accuracy: 0.9966 - val_loss: 1.3033 - val_accuracy: 0.8202
# Epoch 24/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0078 - accuracy: 0.9977 - val_loss: 1.2010 - val_accuracy: 0.8146
# Epoch 25/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 1.2700 - val_accuracy: 0.8194
# Epoch 26/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 1.4697 - val_accuracy: 0.8206
# Epoch 27/50
# 782/782 [==============================] - 14s 18ms/step - loss: 1.9879e-04 - accuracy: 1.0000 - val_loss: 1.5240 - val_accuracy: 0.8193
# Epoch 28/50
# 782/782 [==============================] - 14s 18ms/step - loss: 4.9517e-05 - accuracy: 1.0000 - val_loss: 1.6073 - val_accuracy: 0.8195
# Epoch 29/50
# 782/782 [==============================] - 13s 17ms/step - loss: 2.8642e-05 - accuracy: 1.0000 - val_loss: 1.7040 - val_accuracy: 0.8207
# Epoch 30/50
# 782/782 [==============================] - 13s 17ms/step - loss: 1.8169e-05 - accuracy: 1.0000 - val_loss: 1.7774 - val_accuracy: 0.8204
# Epoch 31/50
# 782/782 [==============================] - 13s 17ms/step - loss: 1.1662e-05 - accuracy: 1.0000 - val_loss: 1.8541 - val_accuracy: 0.8204
# Epoch 32/50
# 782/782 [==============================] - 14s 18ms/step - loss: 7.5075e-06 - accuracy: 1.0000 - val_loss: 1.9381 - val_accuracy: 0.8204
# Epoch 33/50
# 782/782 [==============================] - 14s 18ms/step - loss: 4.8215e-06 - accuracy: 1.0000 - val_loss: 2.0120 - val_accuracy: 0.8208
# Epoch 34/50
# 782/782 [==============================] - 13s 17ms/step - loss: 3.0672e-06 - accuracy: 1.0000 - val_loss: 2.0959 - val_accuracy: 0.8207
# Epoch 35/50
# 782/782 [==============================] - 13s 17ms/step - loss: 1.9434e-06 - accuracy: 1.0000 - val_loss: 2.1771 - val_accuracy: 0.8206
# Epoch 36/50
# 782/782 [==============================] - 13s 17ms/step - loss: 1.2170e-06 - accuracy: 1.0000 - val_loss: 2.2728 - val_accuracy: 0.8209
# Epoch 37/50
# 782/782 [==============================] - 14s 18ms/step - loss: 7.6658e-07 - accuracy: 1.0000 - val_loss: 2.3635 - val_accuracy: 0.8208
# Epoch 38/50
# 782/782 [==============================] - 14s 18ms/step - loss: 4.7938e-07 - accuracy: 1.0000 - val_loss: 2.4595 - val_accuracy: 0.8204
# Epoch 39/50
# 782/782 [==============================] - 13s 17ms/step - loss: 3.0357e-07 - accuracy: 1.0000 - val_loss: 2.5472 - val_accuracy: 0.8201
# Epoch 40/50
# 782/782 [==============================] - 13s 17ms/step - loss: 1.9390e-07 - accuracy: 1.0000 - val_loss: 2.6301 - val_accuracy: 0.8196
# Epoch 41/50
# 782/782 [==============================] - 13s 17ms/step - loss: 1.2232e-07 - accuracy: 1.0000 - val_loss: 2.7326 - val_accuracy: 0.8197
# Epoch 42/50
# 782/782 [==============================] - 14s 18ms/step - loss: 8.0794e-08 - accuracy: 1.0000 - val_loss: 2.7526 - val_accuracy: 0.8192
# Epoch 43/50
# 782/782 [==============================] - 14s 18ms/step - loss: 5.1684e-08 - accuracy: 1.0000 - val_loss: 2.8988 - val_accuracy: 0.8192
# Epoch 44/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0280 - accuracy: 0.9922 - val_loss: 1.4043 - val_accuracy: 0.8111
# Epoch 45/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0240 - accuracy: 0.9912 - val_loss: 1.1463 - val_accuracy: 0.8177
# Epoch 46/50
# 782/782 [==============================] - 13s 17ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 1.2539 - val_accuracy: 0.8139
# Epoch 47/50
# 782/782 [==============================] - 13s 17ms/step - loss: 5.5442e-04 - accuracy: 0.9999 - val_loss: 1.3581 - val_accuracy: 0.8166
# Epoch 48/50
# 782/782 [==============================] - 13s 17ms/step - loss: 6.8104e-04 - accuracy: 0.9998 - val_loss: 1.5754 - val_accuracy: 0.8120
# Epoch 49/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0118 - accuracy: 0.9962 - val_loss: 1.3927 - val_accuracy: 0.8081
# Epoch 50/50
# 782/782 [==============================] - 14s 18ms/step - loss: 0.0073 - accuracy: 0.9980 - val_loss: 1.2098 - val_accuracy: 0.8141

# %% [markdown]
# # Model Definition with Conv1D

# %%
# Model Definition with Conv1D
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

history = model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 120, 16)           160000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 116, 128)          10368
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 6)                 774
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 171,149
# Trainable params: 171,149
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 782/782 [==============================] - 34s 9ms/step - loss: 0.5359 - accuracy: 0.7704 - val_loss: 0.4479 - val_accuracy: 0.8363
# Epoch 2/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.3675 - accuracy: 0.8771 - val_loss: 0.4127 - val_accuracy: 0.8323
# Epoch 3/50
# 782/782 [==============================] - 7s 9ms/step - loss: 0.2868 - accuracy: 0.9068 - val_loss: 0.4114 - val_accuracy: 0.8378
# Epoch 4/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.2318 - accuracy: 0.9276 - val_loss: 0.4380 - val_accuracy: 0.8324
# Epoch 5/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.1957 - accuracy: 0.9403 - val_loss: 0.5065 - val_accuracy: 0.8293
# Epoch 6/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.1649 - accuracy: 0.9512 - val_loss: 0.5679 - val_accuracy: 0.8264
# Epoch 7/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.1429 - accuracy: 0.9599 - val_loss: 0.5954 - val_accuracy: 0.8141
# Epoch 8/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.1280 - accuracy: 0.9650 - val_loss: 0.7212 - val_accuracy: 0.8215
# Epoch 9/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.1175 - accuracy: 0.9694 - val_loss: 0.8128 - val_accuracy: 0.8175
# Epoch 10/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.1131 - accuracy: 0.9700 - val_loss: 0.8235 - val_accuracy: 0.8152
# Epoch 11/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.1079 - accuracy: 0.9719 - val_loss: 0.8252 - val_accuracy: 0.8066
# Epoch 12/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.1051 - accuracy: 0.9728 - val_loss: 1.0545 - val_accuracy: 0.8177
# Epoch 13/50
# 782/782 [==============================] - 7s 9ms/step - loss: 0.1037 - accuracy: 0.9734 - val_loss: 0.9693 - val_accuracy: 0.8135
# Epoch 14/50
# 782/782 [==============================] - 7s 9ms/step - loss: 0.1002 - accuracy: 0.9748 - val_loss: 0.9822 - val_accuracy: 0.8066
# Epoch 15/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.1035 - accuracy: 0.9733 - val_loss: 1.1234 - val_accuracy: 0.8122
# Epoch 16/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.1043 - accuracy: 0.9725 - val_loss: 1.0200 - val_accuracy: 0.8076
# Epoch 17/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.0990 - accuracy: 0.9752 - val_loss: 1.0703 - val_accuracy: 0.8054
# Epoch 18/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.0962 - accuracy: 0.9764 - val_loss: 1.1813 - val_accuracy: 0.8119
# Epoch 19/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.0949 - accuracy: 0.9768 - val_loss: 1.2475 - val_accuracy: 0.8130
# Epoch 20/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.1001 - accuracy: 0.9747 - val_loss: 1.1957 - val_accuracy: 0.8106
# Epoch 21/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.1025 - accuracy: 0.9734 - val_loss: 1.1417 - val_accuracy: 0.8092
# Epoch 22/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.1001 - accuracy: 0.9749 - val_loss: 1.1830 - val_accuracy: 0.8092
# Epoch 23/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.0964 - accuracy: 0.9761 - val_loss: 1.3491 - val_accuracy: 0.8132
# Epoch 24/50
# 782/782 [==============================] - 6s 8ms/step - loss: 0.0974 - accuracy: 0.9754 - val_loss: 1.3122 - val_accuracy: 0.8113
# Epoch 25/50
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0971 - accuracy: 0.9756 - val_loss: 1.2902 - val_accuracy: 0.8122
# Epoch 26/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.0940 - accuracy: 0.9772 - val_loss: 1.2377 - val_accuracy: 0.8128
# Epoch 27/50
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0909 - accuracy: 0.9782 - val_loss: 1.1983 - val_accuracy: 0.8080
# Epoch 28/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.0919 - accuracy: 0.9779 - val_loss: 1.1986 - val_accuracy: 0.8102
# Epoch 29/50
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0950 - accuracy: 0.9763 - val_loss: 1.1931 - val_accuracy: 0.8011
# Epoch 30/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.0983 - accuracy: 0.9751 - val_loss: 1.2676 - val_accuracy: 0.8094
# Epoch 31/50
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0967 - accuracy: 0.9758 - val_loss: 1.3724 - val_accuracy: 0.8129
# Epoch 32/50
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0923 - accuracy: 0.9779 - val_loss: 1.1835 - val_accuracy: 0.8050
# Epoch 33/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.0900 - accuracy: 0.9784 - val_loss: 1.4280 - val_accuracy: 0.8100
# Epoch 34/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.0902 - accuracy: 0.9783 - val_loss: 1.4237 - val_accuracy: 0.8098
# Epoch 35/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.0914 - accuracy: 0.9775 - val_loss: 1.4235 - val_accuracy: 0.8121
# Epoch 36/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.0925 - accuracy: 0.9774 - val_loss: 1.3228 - val_accuracy: 0.8071
# Epoch 37/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.0917 - accuracy: 0.9776 - val_loss: 1.4207 - val_accuracy: 0.8107
# Epoch 38/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.0908 - accuracy: 0.9779 - val_loss: 1.4875 - val_accuracy: 0.8112
# Epoch 39/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.0913 - accuracy: 0.9776 - val_loss: 1.3455 - val_accuracy: 0.8092
# Epoch 40/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.0897 - accuracy: 0.9783 - val_loss: 1.3219 - val_accuracy: 0.8045
# Epoch 41/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.0887 - accuracy: 0.9788 - val_loss: 1.2127 - val_accuracy: 0.7978
# Epoch 42/50
# 782/782 [==============================] - 7s 9ms/step - loss: 0.0889 - accuracy: 0.9787 - val_loss: 1.6823 - val_accuracy: 0.8093
# Epoch 43/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.0935 - accuracy: 0.9768 - val_loss: 1.1461 - val_accuracy: 0.7956
# Epoch 44/50
# 782/782 [==============================] - 6s 7ms/step - loss: 0.0942 - accuracy: 0.9764 - val_loss: 1.3301 - val_accuracy: 0.8096
# Epoch 45/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.0898 - accuracy: 0.9782 - val_loss: 1.6273 - val_accuracy: 0.8122
# Epoch 46/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.0881 - accuracy: 0.9789 - val_loss: 1.3812 - val_accuracy: 0.8095
# Epoch 47/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.0878 - accuracy: 0.9792 - val_loss: 1.2980 - val_accuracy: 0.8053
# Epoch 48/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.0898 - accuracy: 0.9781 - val_loss: 1.5636 - val_accuracy: 0.8135
# Epoch 49/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.0939 - accuracy: 0.9765 - val_loss: 1.3538 - val_accuracy: 0.8088
# Epoch 50/50
# 782/782 [==============================] - 5s 7ms/step - loss: 0.0903 - accuracy: 0.9782 - val_loss: 1.3044 - val_accuracy: 0.8085
